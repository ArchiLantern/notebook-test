#  ('2022-06-29 19:38:53', '暂停'),
#  ('2022-06-28 22:00:28', '开始')]

# %%
import re
the_time = re.findall('(\d+-\d+-\d+ \d+:\d+:\d+)\n\d+-[KBWkbw]+.S (\w+)\n', ''.join(log))
the_time
# Out:
# [('2022-07-01 18:31:57', '开始'),
#  ('2022-07-01 03:14:01', '完成'),
#  ('2022-06-30 18:09:17', '开始'),
#  ('2022-06-30 10:06:34', '完成'),
#  ('2022-06-30 10:06:34', '开始'),
#  ('2022-06-29 19:38:53', '暂停'),
#  ('2022-06-28 22:00:28', '开始')]

# %%
df = pd.DataFrame(the_time, columns=['time', 'flag'])
display(df)
df.dtypes
# Out:
#                   time flag
# 0  2022-07-01 18:31:57   开始
# 1  2022-07-01 03:14:01   完成
# 2  2022-06-30 18:09:17   开始
# 3  2022-06-30 10:06:34   完成
# 4  2022-06-30 10:06:34   开始
# 5  2022-06-29 19:38:53   暂停
# 6  2022-06-28 22:00:28   开始
# time    object
# flag    object
# dtype: object

# %%
df = pd.DataFrame(the_time, columns=['time', 'flag'])
display(df.time.dtypes )

# 方法一：用 astype('time': 'datetime64')
# df.astype({'time': 'datetime'})   # 无法识别
# df = df.astype({'time': 'datetime64[ns]'})
df = df.astype({'time': 'datetime64'})
df.dtypes
# Out:
# dtype('O')
# time    datetime64[ns]
# flag            object
# dtype: object

# %%
df = pd.DataFrame(the_time, columns=['time', 'flag'])
display(df.time.dtypes )   

# 方法二： pd.to_datetime(str_date, format)
df.time = pd.to_datetime(df.time, )
df.dtypes
# Out:
# dtype('O')
# time    datetime64[ns]
# flag            object
# dtype: object

# %%
df = pd.DataFrame(the_time, columns=['time', 'flag'])
display(df.time.dtypes )

# 方法三： df['time']=df['time'].apply(lambda _: datetime.strptime(str(_), format))
from datetime import datetime 
df.time = df.time.apply(lambda _:datetime.strptime(str(_), '%Y-%m-%d %H:%M:%S'))
df.dtypes
# Out:
# dtype('O')
# time    datetime64[ns]
# flag            object
# dtype: object

# %%
display(df.time.dtypes)  # 注： <M8[ns]属于一种datetime64[ns]

df.time - pd.Timedelta(days = 1)
# Out:
# dtype('<M8[ns]')
# 0   2022-06-30 18:31:57
# 1   2022-06-30 03:14:01
# 2   2022-06-29 18:09:17
# 3   2022-06-29 10:06:34
# 4   2022-06-29 10:06:34
# 5   2022-06-28 19:38:53
# 6   2022-06-27 22:00:28
# Name: time, dtype: datetime64[ns]

# %%
df0 = df.sort_values('time').reset_index(drop=True)
df0
# Out:
#                  time flag
# 0 2022-06-28 22:00:28   开始
# 1 2022-06-29 19:38:53   暂停
# 2 2022-06-30 10:06:34   完成
# 3 2022-06-30 10:06:34   开始
# 4 2022-06-30 18:09:17   开始
# 5 2022-07-01 03:14:01   完成
# 6 2022-07-01 18:31:57   开始

# %%
df1 = df.sort_values('time').reset_index(drop=True).shift()
df1
# Out:
#                  time flag
# 0                 NaT  NaN
# 1 2022-06-28 22:00:28   开始
# 2 2022-06-29 19:38:53   暂停
# 3 2022-06-30 10:06:34   完成
# 4 2022-06-30 10:06:34   开始
# 5 2022-06-30 18:09:17   开始
# 6 2022-07-01 03:14:01   完成

# %%
res = pd.concat([df0, df1], axis=1)
res.columns = ['t1', 'f1', 't2', 'f2']
res
# Out:
#                    t1  f1                  t2   f2
# 0 2022-06-28 22:00:28  开始                 NaT  NaN
# 1 2022-06-29 19:38:53  暂停 2022-06-28 22:00:28   开始
# 2 2022-06-30 10:06:34  完成 2022-06-29 19:38:53   暂停
# 3 2022-06-30 10:06:34  开始 2022-06-30 10:06:34   完成
# 4 2022-06-30 18:09:17  开始 2022-06-30 10:06:34   开始
# 5 2022-07-01 03:14:01  完成 2022-06-30 18:09:17   开始
# 6 2022-07-01 18:31:57  开始 2022-07-01 03:14:01   完成

# %%
# 分两种情况，过滤出需要的时间记录

result = res[ ((res.f1 == '暂停') & (res.f2 == '开始')) |
              ((res.f1 == '完成') & (res.f2 == '开始')) ].loc[:]  
              # 加上.loc[:] 是为了避免后面的SettingWithCopy警告，类似动态修改列表需要切片一样
              # https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
result
# Out:
#                    t1  f1                  t2  f2
# 1 2022-06-29 19:38:53  暂停 2022-06-28 22:00:28  开始
# 5 2022-07-01 03:14:01  完成 2022-06-30 18:09:17  开始

# %%
# 计算时间差
result['used_time'] = result.t1 - result.t2 
display(result)
# Out:
#                    t1  f1                  t2  f2       used_time
# 1 2022-06-29 19:38:53  暂停 2022-06-28 22:00:28  开始 0 days 21:38:25
# 5 2022-07-01 03:14:01  完成 2022-06-30 18:09:17  开始 0 days 09:04:44

# %%
# 统计时间（设备使用的总时间）
result.agg({'used_time': sum}, )
# Out:
# used_time   1 days 06:43:09
# dtype: timedelta64[ns]

# %%
type(result.agg({'used_time': sum}, ))
# Out:
# pandas.core.series.Series

# %%
print(result.agg)
# Out:
# <bound method DataFrame.aggregate of                    t1  f1                  t2  f2       used_time
# 1 2022-06-29 19:38:53  暂停 2022-06-28 22:00:28  开始 0 days 21:38:25
# 5 2022-07-01 03:14:01  完成 2022-06-30 18:09:17  开始 0 days 09:04:44>

# %%
# result[['t1','t2', 'used_time']].pivot_table(index=['t1', 't2'], aggfunc='sum', margins=True, margins_name='合计')
# result.pivot_table(index=['f1','t1', 'f2','t2'], aggfunc='sum', margins=True, margins_name='合计')

result.pivot_table(index=['t1','t2'], aggfunc='sum', margins=True, margins_name='合计')
# Out:
# C:\Users\Administrator\AppData\Local\Temp\ipykernel_11100\4273375783.py:4: FutureWarning: Inferring datetime64[ns] from data containing strings is deprecated and will be removed in a future version. To retain the old behavior explicitly pass Series(data, dtype=datetime64[ns])
#   result.pivot_table(index=['t1','t2'], aggfunc='sum', margins=True, margins_name='合计')
#                                            f1    f2       used_time
# t1                  t2
# 2022-06-29 19:38:53 2022-06-28 22:00:28    暂停    开始 0 days 21:38:25
# 2022-07-01 03:14:01 2022-06-30 18:09:17    完成    开始 0 days 09:04:44
# 合计                  NaT                  暂停完成  开始开始 1 days 06:43:09

# %%
# 
# 追加行      （综合案例见：如何添加"汇总行"？ ）
# df.append(dict(zip(df.columns, list_data)), ignore_index=True)  
# df.loc[len(df)] = list_data  
# pd.concat([df1, dict-like_df2], axis=0)
# df.pivot_table(..., margins=True, ...) 

# 添加"汇总行"，如 
df = pd.DataFrame({'名称': ['a','a','b','c'], '金额':[100, 100, 120, 150]})
df.pivot_table(index='名称', aggfunc='sum', margins=True, margins_name='合计：').sort_values('金额').reset_index()
# Out:
#     名称   金额
# 0    b  120
# 1    c  150
# 2    a  200
# 3  合计：  470
